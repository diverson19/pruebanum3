# %% [markdown]
# <a href="https://colab.research.google.com/github/diverson19/pruebanum3/blob/main/Caso_registro_civil_prueba3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
from IPython.display import clear_output
personas = []
def validar_rut(rut):
  rut = rut.replace(".", "").replace("-", "")
  if len(rut) != 9 or not rut[:-1].isdigit():
    return False
  multiplicadores = [2, 3, 4, 5, 6, 7, 2, 3]
  total = sum(int(digito) * multiplicador for digito, multiplicador in zip(rut[:-1][::-1], multiplicadores))
  resto = total % 11
  digito_verificador = str(11 - resto)
  if digito_verificador == "11":
    digito_verificador = "0"
  elif digito_verificador == "10":
    digito_verificador = "K"
  return rut[-1].upper() == digito_verificador

def grabar_persona():
  rut = input("Digite el RUT de la persona (con un formato correcto: XX.XXX.XXX-X): ")
  while not validar_rut(rut):
    print("RUT inválido. Por favor, Digite nuevamente.")
    rut = input("Digite el RUT de la persona (con un formato correcto: XX.XXX.XXX-X): ")
  nombre = input("Ingrese el nombre de la persona: ")
  while len(nombre) < 8:
    print("El nombre debe tener al menos 8 caracteres.")
    nombre = input("Ingrese el nombre de la persona: ")
  edad = int(input("Ingrese la edad de la persona: "))
  while edad < 0:
    print("La edad tiene que ser mayor o igual a 0.")
    edad = int(input("Ingrese la edad de la persona: "))
  pais_nacimiento = input("Ingrese el país de nacimiento de la persona: ")
  ciudad_nacimiento = input("Ingrese la ciudad de nacimiento de la persona: ")
  persona = {
    "rut": rut,
    "nombre": nombre,
    "edad": edad,
    "pais_nacimiento": pais_nacimiento,
    "ciudad_nacimiento": ciudad_nacimiento}
  personas.append(persona)
  clear_output()
  print("Datos guardados con exito.")

def buscar_persona():
  rut = input("Ingrese el RUT de la persona que quieres buscar: ")
  for persona in personas:
    if persona["rut"] == rut:
      print("Información de la persona que quieres buscar:")
      print(f"RUT: {persona['rut']}")
      print(f"Nombre: {persona['nombre']}")
      print(f"Edad: {persona['edad']}")
      print(f"País de nacimiento: {persona['pais_nacimiento']}")
      print(f"Ciudad de nacimiento: {persona['ciudad_nacimiento']}")
      if persona['pais_nacimiento'].lower() == 'chile':
        print("La persona pertenece al país de Chile.")
      return
  print("lo siento no hemos encontrado a ninguna persona con ese RUT.")

def imprimir_certificados():
  certificados = [
    {
      "nombre": "Certificado de Nacimiento",
      "codigo": "CN"},
    {
      "nombre": "Estado Conyugal",
      "codigo": "EC"},
    {
      "nombre": "Perteneciente a Chile",
      "codigo": "PC"}
    ]
  for certificado in certificados:
    print(f"Nombre del certificado: {certificado['nombre']}")
    rut = input("Ingrese el RUT de la persona: ")
    for persona in personas:
      if persona["rut"] == rut:
        print(f"RUT de la persona: {persona['rut']}")
        print(f"Nombre de la persona: {persona['nombre']}")
        print(f"Datos adicionales del certificado {certificado['codigo']}")

def eliminar_persona():
  rut = input("Ingrese el RUT de la persona que quieres eliminar: ")
  for persona in personas:
    if persona["rut"] == rut:
      personas.remove(persona)
      print("La persona ha sido eliminada exitosamente.")
      return
  print("lo siento no hemos encontrado a ninguna persona con ese RUT.")

def imprimir_menu():
  print("\n-----------------------MENÚ --------------------")
  print("1. Grabar")
  print("2. Buscar")
  print("3. Imprimir certificados")
  print("4. Eliminar")
  print("5. Salir")

def main():
  print("Bienvenido al programa de TOTEM de autoservicio de atención rápida")
  print("Versión 1.0\n")

  while True:
    imprimir_menu()
    opcion = input("Ingrese el número de la opción que desea seleccionar: ")
    clear_output()
    if opcion == "1":
      grabar_persona()
    elif opcion == "2":
      buscar_persona()
    elif opcion == "3":
      imprimir_certificados()
    elif opcion == "4":
      eliminar_persona()
    elif opcion == "5":
      print("Gracias por utilizar el programa. Hasta luego.")
      break

    else:
      print("Opción inválida. Por favor, tienes que ingresar una opción válida.")
if __name__ == "__main__":
  main()
# Out:
# Gracias por utilizar el programa. Hasta luego.
